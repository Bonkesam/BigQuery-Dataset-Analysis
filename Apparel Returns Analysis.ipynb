# %% [markdown]
# # Apparel Returns Analysis

# %%
#First we import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading the dataset

data = pd.read_csv('Apparel_Revenue.csv')
data.head(5)
# Out:
#          fullVisitorId channelGrouping    time        country  \
# 0  9641690225668962441          Direct  394455  United States
# 1  9641690225668962441          Direct  394455  United States
# 2  9991458465328295712          Direct  627242  United States
# 3  9991458465328295712          Direct  627242  United States
# 4  9991458465328295712          Direct  627242  United States
#
#                             city  totalTransactionRevenue  transactions  \
# 0  not available in demo dataset                 31090000             1
# 1  not available in demo dataset                 31090000             1
# 2  not available in demo dataset                991730000             1
# 3  not available in demo dataset                991730000             1
# 4  not available in demo dataset                991730000             1
#
#    timeOnSite  pageviews  sessionQualityDim  ... v2ProductCategory  \
# 0        1306         19                 86  ...           Apparel
# ...

# %%
#Let us check the shape of the data

data.shape
# Out:
# (104, 29)
